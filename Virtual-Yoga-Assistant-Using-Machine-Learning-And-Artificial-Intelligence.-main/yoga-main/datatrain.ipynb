# %%
import os
import numpy as np
from tensorflow.keras.utils import to_categorical
from keras.layers import Input, Dense
from keras.models import Model

# Initialize variables
label = []
dictionary = {}
c = 0

# Collect data from .npy files
X = None
y = None
for filename in os.listdir():
    if filename.endswith(".npy") and not filename.startswith("labels"):
        data = np.load(filename)
        if X is None:
            X = data
            y = np.full((data.shape[0], 1), filename.split('.')[0])
        else:
            X = np.concatenate((X, data))
            y = np.concatenate((y, np.full((data.shape[0], 1), filename.split('.')[0])))

        label.append(filename.split('.')[0])
        dictionary[filename.split('.')[0]] = c
        c += 1

# Convert labels to integers and then to one-hot encoding
y = np.vectorize(dictionary.get)(y)
y = to_categorical(y)

# Shuffle data
indices = np.arange(X.shape[0])
np.random.shuffle(indices)
X = X[indices]
y = y[indices]

# Define model architecture
ip = Input(shape=(X.shape[1],))
m = Dense(128, activation="tanh")(ip)
m = Dense(64, activation="tanh")(m)
op = Dense(y.shape[1], activation="softmax")(m)

model = Model(inputs=ip, outputs=op)

# Compile and train model
model.compile(optimizer='rmsprop', loss="categorical_crossentropy", metrics=['acc'])
model.fit(X, y, epochs=80)

# Save model and labels
model.save("model.h5")
np.save("labels.npy", np.array(label))
# Out:
# Epoch 1/80
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - acc: 0.2453 - loss: 1.9237
# Epoch 2/80
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 0.4594 - loss: 1.6130
# Epoch 3/80
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 0.5440 - loss: 1.3736
# Epoch 4/80
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 0.6068 - loss: 1.2103
# Epoch 5/80
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6443 - loss: 1.0711
# Epoch 6/80
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7199 - loss: 0.9653
# Epoch 7/80
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - acc: 0.7805 - loss: 0.9074
# Epoch 8/80
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 0.7965 - loss: 0.8085
# Epoch 9/80
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 0.8156 - loss: 0.7120
# Epoch 10/80
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.8352 - loss: 0.6773
# Epoch 11/80
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.8235 - loss: 0.6487
# Epoch 12/80
# ...
